# %%
# %run Credit_DataWrangling.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   checking_status         1000 non-null   object
#  1   duration                1000 non-null   float64
#  2   credit_history          1000 non-null   object
#  3   purpose                 1000 non-null   object
#  4   credit_amount           1000 non-null   float64
#  5   savings_status          1000 non-null   object
#  6   employment              1000 non-null   object
#  7   installment_commitment  1000 non-null   float64
#  8   personal_status         1000 non-null   object
#  9   other_parties           1000 non-null   object
#  10  residence_since         1000 non-null   float64
#  11  property_magnitude      1000 non-null   object
#  12  age                     1000 non-null   float64
#  13  other_payment_plans     1000 non-null   object
# ...

# %%
# %run Credit_DataEDA.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   checking_status         1000 non-null   object
#  1   duration                1000 non-null   float64
#  2   credit_history          1000 non-null   object
#  3   purpose                 1000 non-null   object
#  4   credit_amount           1000 non-null   float64
#  5   savings_status          1000 non-null   object
#  6   employment              1000 non-null   object
#  7   installment_commitment  1000 non-null   float64
#  8   personal_status         1000 non-null   object
#  9   other_parties           1000 non-null   object
#  10  residence_since         1000 non-null   float64
#  11  property_magnitude      1000 non-null   object
#  12  age                     1000 non-null   float64
#  13  other_payment_plans     1000 non-null   object
# ...

# %%
credit_data.dtypes
# Out:
# checking_status            object
# duration                  float64
# credit_history             object
# purpose                    object
# credit_amount             float64
# savings_status             object
# employment                 object
# installment_commitment    float64
# personal_status            object
# other_parties              object
# residence_since           float64
# property_magnitude         object
# age                       float64
# other_payment_plans        object
# housing                    object
# existing_credits          float64
# job                        object
# num_dependents            float64
# own_telephone              object
# foreign_worker             object
# class                      object
# dtype: object

# %%
import numpy as np
import pandas as pd

#Using only the features that are needed to address the hypotheses

checking_status_data = credit_data[['checking_status', 'class']]
checking_status_data.head()
# Out:
#   checking_status class
# 0              <0  good
# 1        0<=X<200   bad
# 2     no checking  good
# 3              <0  good
# 4              <0   bad

# %%
#Observing the unique elements of each of the columns
print(checking_status_data['checking_status'].unique())
print(checking_status_data['class'].unique())
# Out:
# ['<0' '0<=X<200' 'no checking' '>=200']
# ['good' 'bad']

# %%
#Getting a count of each of the values in the features of the dataframe

checking_status_data['checking_status'].value_counts()
# Out:
# no checking    394
# <0             274
# 0<=X<200       269
# >=200           63
# Name: checking_status, dtype: int64

# %%
#Same as above

checking_status_data['class'].value_counts()
# Out:
# good    700
# bad     300
# Name: class, dtype: int64

# %%
#One-Hot encoding of categorical columns using Pandas' get_dummies method

checking_status_one_hot = pd.get_dummies(checking_status_data, columns=['checking_status'])
print(checking_status_one_hot)
# Out:
#     class  checking_status_0<=X<200  checking_status_<0  \
# 0    good                         0                   1
# 1     bad                         1                   0
# 2    good                         0                   0
# 3    good                         0                   1
# 4     bad                         0                   1
# ..    ...                       ...                 ...
# 995  good                         0                   0
# 996  good                         0                   1
# 997  good                         0                   0
# 998   bad                         0                   1
# 999  good                         1                   0
#
#      checking_status_>=200  checking_status_no checking
# 0                        0                            0
# 1                        0                            0
# 2                        0                            1
# 3                        0                            0
# ...

# %%
#Using only the features that are needed to address the hypotheses

credit_history_data = credit_data[['credit_history', 'class']]
credit_history_data.head()
# Out:
#                    credit_history class
# 0  critical/other existing credit  good
# 1                   existing paid   bad
# 2  critical/other existing credit  good
# 3                   existing paid  good
# 4              delayed previously   bad

# %%
#Observing the unique elements of each of the columns
print(credit_history_data['credit_history'].unique())
print(credit_history_data['class'].unique())
# Out:
# ['critical/other existing credit' 'existing paid' 'delayed previously'
#  'no credits/all paid' 'all paid']
# ['good' 'bad']

# %%
#Getting a count of each of the values of the features of the dataframe

credit_history_data['credit_history'].value_counts()
# Out:
# existing paid                     530
# critical/other existing credit    293
# delayed previously                 88
# all paid                           49
# no credits/all paid                40
# Name: credit_history, dtype: int64

# %%
#Same as above

credit_history_data['class'].value_counts()
# Out:
# good    700
# bad     300
# Name: class, dtype: int64

# %%
#One-Hot encoding of categorical columns using Pandas' get_dummies method

credit_history_one_hot = pd.get_dummies(credit_history_data, columns=['credit_history'])
print(credit_history_one_hot)
# Out:
#     class  credit_history_all paid  \
# 0    good                        0
# 1     bad                        0
# 2    good                        0
# 3    good                        0
# 4     bad                        0
# ..    ...                      ...
# 995  good                        0
# 996  good                        0
# 997  good                        0
# 998   bad                        0
# 999  good                        0
#
#      credit_history_critical/other existing credit  \
# 0                                                1
# 1                                                0
# 2                                                1
# 3                                                0
# 4                                                0
# ..                                             ...
# 995                                              0
# 996                                              0
# 997                                              0
# ...

# %%
#Using only the features that are needed to address the hypotheses
employment_data = credit_data[['employment', 'class']]
employment_data.head()
# Out:
#   employment class
# 0        >=7  good
# 1     1<=X<4   bad
# 2     4<=X<7  good
# 3     4<=X<7  good
# 4     1<=X<4   bad

# %%
#Observing the unique elements of each of the columns
print(employment_data['employment'].unique())
print(employment_data['class'].unique())
# Out:
# ['>=7' '1<=X<4' '4<=X<7' 'unemployed' '<1']
# ['good' 'bad']

# %%
#Getting a count of each of the values of the features of the dataframe

employment_data['employment'].value_counts()
# Out:
# 1<=X<4        339
# >=7           253
# 4<=X<7        174
# <1            172
# unemployed     62
# Name: employment, dtype: int64

# %%
#Same as above

employment_data['class'].value_counts()
# Out:
# good    700
# bad     300
# Name: class, dtype: int64

# %%
#One-Hot encoding of categorical columns using Pandas' get_dummies method

employment_data_one_hot = pd.get_dummies(employment_data, columns=['employment'])
print(employment_data_one_hot)
# Out:
#     class  employment_1<=X<4  employment_4<=X<7  employment_<1  \
# 0    good                  0                  0              0
# 1     bad                  1                  0              0
# 2    good                  0                  1              0
# 3    good                  0                  1              0
# 4     bad                  1                  0              0
# ..    ...                ...                ...            ...
# 995  good                  0                  1              0
# 996  good                  1                  0              0
# 997  good                  0                  0              0
# 998   bad                  1                  0              0
# 999  good                  0                  0              0
#
#      employment_>=7  employment_unemployed
# 0                 1                      0
# 1                 0                      0
# 2                 0                      0
# ...

# %%
#Revising this dataframe as the class feature won't be needed as it's included in the first dataframe
credit_history_one_hot2 = credit_history_one_hot.drop(['class'], axis=1)

# %%
#Revising this dataframe as the class feature won't be needed as it's included in the second dataframe
employment_data_one_hot2 = employment_data_one_hot.drop(['class'], axis=1)

# %%
#Combining all of the afore dataframes into one to also use as input into an SVM

merged_credit_data = pd.concat([checking_status_one_hot, credit_history_one_hot2, employment_data_one_hot2], axis=1)
print("Merged dataframe is:")
print(merged_credit_data)
# Out:
# Merged dataframe is:
#     class  checking_status_0<=X<200  checking_status_<0  \
# 0    good                         0                   1
# 1     bad                         1                   0
# 2    good                         0                   0
# 3    good                         0                   1
# 4     bad                         0                   1
# ..    ...                       ...                 ...
# 995  good                         0                   0
# 996  good                         0                   1
# 997  good                         0                   0
# 998   bad                         0                   1
# 999  good                         1                   0
#
#      checking_status_>=200  checking_status_no checking  \
# 0                        0                            0
# 1                        0                            0
# 2                        0                            1
# ...
